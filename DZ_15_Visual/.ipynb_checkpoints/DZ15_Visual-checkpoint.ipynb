# %% [markdown]
# # Домашнее задание к лекции "Визуализация данных"
# # Обязательная часть
# # Вам необходимо провести базовый EDA выбранного набора данных.
# #
# # Требования к анализу:
#
# # построить не менее 4 визуализаций различных видов;
# # каждая визуализация должным образом оформлена и читается даже в отрыве от контекста;
# # по каждой визуализации необходимо написать вывод (какую гипотезу на ее основе можно выдвинуть?).
# # Откуда брать данные?
#
# # Можете взять свои рабочие данные, либо найти открытые данные (например, на kaggle.com) по интересующей вас предметной области (тогда не забудьте их выложить на github вместе с ноутбуком). Если идей нет, можете взять один из перечисленных ниже:
#
# # данные приложений из Google Play;
# # данные о видео из трендов YouTube;
# # данные об уровне счастья в разных странах.

# %% [markdown]
# Для проведения EDA выбран датасет https://www.kaggle.com/palanjali007/amazons-top-50-bestselling-novels-20092020

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 13,6

# %%
df = pd.read_csv('Amazon_books.csv')

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User_rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
#переименование столбца с пробелом
df = df.rename(columns={'User Rating': 'User_rating'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         600 non-null    object
#  1   Author       600 non-null    object
#  2   User_rating  600 non-null    float64
#  3   Reviews      600 non-null    int64
#  4   Price        600 non-null    int64
#  5   Year         600 non-null    int64
#  6   Genre        600 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 32.9+ KB

# %%
df.describe()
# Out:
#        User_rating        Reviews      Price         Year
# count   600.000000     600.000000  600.00000   600.000000
# mean      4.627333   13941.730000   12.92000  2014.500000
# std       0.225324   14652.813591   10.49717     3.454933
# min       3.300000      37.000000    0.00000  2009.000000
# 25%       4.500000    4586.500000    7.00000  2011.750000
# 50%       4.700000    9059.500000   11.00000  2014.500000
# 75%       4.800000   19587.500000   16.00000  2017.250000
# max       4.900000  120727.000000  105.00000  2020.000000

# %% [markdown]
# # Вывод №1. Распределение по жанрам книг: 56,17% - "нон-фикшн" (на реальных событиях, фактах, документальная проза), 43,83% - "фикшн" (художественная литература, вымысел). Характеризует целевую аудиторию Amazon.

# %%
df.Genre.value_counts().plot.pie(title= 'Genres share', autopct='%1.2f%%')
# Out:
# <AxesSubplot:title={'center':'Genres share'}, ylabel='Genre'>

# %% [markdown]
# # Вывод №2. Распределение оценок читателей в основном в диапазоне 4.4 - 4.8 (как правило, читатели высоко оценивают книги, которые прочитали)

# %%
# распределение оценок читателей
df.User_rating.plot(kind='hist', 
                     bins=35,
                     title='Распределение оценок читателей',
                     )
# Out:
# <AxesSubplot:title={'center':'Распределение оценок читателей'}, ylabel='Frequency'>

# %% [markdown]
# # Вывод №3. В 2020г. количество отзывов заметно увеличилось (гипотеза о связи с Covid19: пользователи сидели дома, больше читали и оставляли отзывы)

# %%
ax = df[['Year']+['Reviews']].groupby('Year').sum().plot(kind='bar')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

# %% [markdown]
# # Вывод №4. Топ 20 самых обсуждаемых авторов на Amazon (на столбчатой диаграмме). Лидер по отзывам - Susanne Collins
# Сью́зен Ко́ллинз (англ. Suzanne Collins; родилась 10 августа 1962) — американская писательница, автор многочисленных сценариев к детским телепрограммам и мультфильмам, рассказов для детей, а также известная как создательница двух популярных книжных серий для молодежи: «Хроники Подземья» и «Голодные игры». Тираж первых двух романов трилогии «Голодные игры», ставших бестселлерами, превысил 2 миллиона экземпляров[6]. Трилогия экранизирована[7]: в России фильм по первому роману вышел на экраны 22 марта 2012, по второму — 21 ноября 2013, 1-я часть фильма по третьему роману вышла 21 ноября 2014, а 2-я — 19 ноября 2015.

# %%
top20_authors = df[['Name']+['Reviews']+['Author']].groupby(['Author']).sum('Reviews').sort_values(by= 'Reviews', ascending=False).head(20)
bx = top20_authors.plot(kind='bar', ylabel='Reviews', title='TOP20 Authors by Reviews')

# %%
import seaborn as sns

# %% [markdown]
# # Вывод № 5. Прослеживается прямая связь между количеством отзывов и оценками пользователей (чем больше отзывов, тем лучше оценки).

# %%
ax = sns.regplot(data=df, x='User_rating', y='Reviews', color='green', marker='+')
ax.set_title('Correlation between Revews and User_rating')
# Out:
# Text(0.5, 1.0, 'Correlation between Revews and User_rating')

# %% [markdown]
# # Вывод № 6. Прослеживается обратная связь между ценой и оценками пользователей (гипотеза: цена книги не влияет на пользовательскую оценку, более того существует некоторая обратная связь (очень много одновременно недорогих и высоко оцененных книг)

# %%
ax = sns.regplot(data=df, x='User_rating', y='Price', color='green', marker='+')
ax.set_title('Correlation between Price and User Rating')
# Out:
# Text(0.5, 1.0, 'Correlation between Price and User Rating')

# %% [markdown]
# # Вывод № 7. Топ 5 книг по количеству отзывов (оценки пользователей от 4.7 до 4.9):
# # 1-е место - Where The Crawdads Sing (4.8) (Там, где раки поют Делия Оуэнс
# Подробнее на livelib.ru:
# https://www.livelib.ru/book/1003447265-tam-gde-raki-poyut-deliya-ouens
#
# # 2-е место - The Fault in Our Stars (4.7)  (Виноваты Звезды), John Green
# Подробнее на livelib.ru:
# https://www.livelib.ru/book/1000503048/reviews-the-fault-in-our-stars-john-green
#
# # 3-е место - Oh, the Places You'll Go! (4.9) Теодор Сьюсс Гейсел
# Подробнее на livelib.ru:
# https://www.livelib.ru/book/1001419507-oh-the-places-youll-go-teodor-syuss-gejsel
#
# # 4-е место - The Very Hungry Caterpillar (4.9) Eric Carle
# Подробнее на livelib.ru:
# https://www.livelib.ru/book/1001809569-the-very-hungry-caterpillar-eric-carle
#
# # 5-е место - The Five Love Languages (4.8) Гэри Чепмен
# Подробнее на livelib.ru:
# https://www.livelib.ru/book/1002760774-the-five-love-languages-singles-edition-geri-chepmen

# %%
top5_books = df[['Name','Reviews','User_rating']].groupby(['Name','User_rating']).sum('Reviews').sort_values(by= 'Reviews', ascending=False).head(5)
cx = top5_books.plot(kind='bar', ylabel='Reviews', title='TOP5 Books by Reviews')
for p in cx.patches:
    cx.annotate(format(p.get_height(), '.1f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')
